# %% [markdown]
# ### **1.Consumo di alcol per paese**
# Esegui un’**analisi esplorativa** focalizzata sul **consumo di alcol**.
# Analizza i seguenti aspetti:
# * Visualizza i primi 10 paesi ordinati per total_litres_of_pure_alcohol (dal più alto)
#
# * Calcola la media del consumo di birra, vino, e distillati
#
# * Crea una nuova colonna alcohol_index che sia: `(beer_servings + wine_servings + spirit_servings) / 3`
#
# * Trova il paese con il valore massimo di alcohol_index
#
# * Filtra solo i paesi che consumano più di 100 birre all’anno
#
# Crea un bar chart dei 10 paesi con più consumo totale (total_litres_of_pure_alcohol)
#
# Crea un line plot con wine_servings ordinato per paese (usa sort_values)

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
df.sort_values(by="total_litres_of_pure_alcohol", ascending=False, inplace=True)
print(df.head(10))
import matplotlib.pyplot as plt

plt.bar(height=df.total_litres_of_pure_alcohol.head(10),x=df.country.head(10))
plt.xticks(rotation=45, ha='right')
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
# 99           Luxembourg            236              133            271
#
#      total_litres_of_pure_alcohol
# 15                           14.4
# 98                           12.9
# 3                            12.4
# 68                           11.9
# ...

# %%
df.beer_servings.mean()
df["alcohol_index"]=(df.beer_servings + df.wine_servings + df.spirit_servings) / 3
df,df.alcohol_index.max()
# Out:
# (            country  beer_servings  spirit_servings  wine_servings  \
#  15          Belarus            142              373             42
#  98        Lithuania            343              244             56
#  3           Andorra            245              138            312
#  68          Grenada            199              438             28
#  45   Czech Republic            361              170            134
#  ..              ...            ...              ...            ...
#  79             Iran              0                0              0
#  90           Kuwait              0                0              0
#  128        Pakistan              0                0              0
#  97            Libya              0                0              0
#  0       Afghanistan              0                0              0
#
#       total_litres_of_pure_alcohol  alcohol_index
#  15                           14.4     185.666667
# ...

# %%
df[df.beer_servings>100]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 15          Belarus            142              373             42
# 98        Lithuania            343              244             56
# 3           Andorra            245              138            312
# 68          Grenada            199              438             28
# 45   Czech Republic            361              170            134
# ..              ...            ...              ...            ...
# 29       Cabo Verde            144               56             16
# 170       Macedonia            106               27             86
# 20          Bolivia            167               41              8
# 146           Samoa            105               18             24
# 189         Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol  alcohol_index
# 15                           14.4     185.666667
# 98                           12.9     214.333333
# ...

# %%
df1=df.sort_values(by="country").head(20)
plt.plot(df1.wine_servings)
plt.title("Wine Servings")
plt.xticks(ticks=range(len(df1.country)),labels=df1.country,rotation=45, ha='right')
# Out:
# ([<matplotlib.axis.XTick at 0x1eba6c2ef00>,
# ...
#  [Text(0, 0, 'Afghanistan'),
#   Text(1, 0, 'Albania'),
#   Text(2, 0, 'Algeria'),
#   Text(3, 0, 'Andorra'),
#   Text(4, 0, 'Angola'),
#   Text(5, 0, 'Antigua & Barbuda'),
#   Text(6, 0, 'Argentina'),
#   Text(7, 0, 'Armenia'),
#   Text(8, 0, 'Australia'),
#   Text(9, 0, 'Austria'),
#   Text(10, 0, 'Azerbaijan'),
#   Text(11, 0, 'Bahamas'),
#   Text(12, 0, 'Bahrain'),
#   Text(13, 0, 'Bangladesh'),
#   Text(14, 0, 'Barbados'),
#   Text(15, 0, 'Belarus'),
#   Text(16, 0, 'Belgium'),
#   Text(17, 0, 'Belize'),
#   Text(18, 0, 'Benin'),
#   Text(19, 0, 'Bhutan')])

# %% [markdown]
# ### **2.Analisi offerte di lavoro**
#
# Esegui un’**analisi esplorativa** focalizzata sui **lavori nel campo dei dati in ciascun paese**.
# Analizza i seguenti aspetti per ogni paese:
#
# * Lo **stipendio medio annuale** (`salary_year_avg`)
# * Il **numero totale di offerte di lavoro** (job count)
# * L’intervallo degli stipendi: **valore minimo e massimo** (`min` / `max`)
#
# Rappresenta graficamente lo stipendio medio (`salary_year_avg`) per `job_title_short` usando un grafico a barre orizzontali. Ordina i dati dallo stipendio più alto al più basso. Includi un titolo e le etichette per gli assi x e y.

# %%
import pandas as pd

from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
import numpy as np

df1=df.dropna(subset=["salary_year_avg"], )
df1.groupby("job_country")["salary_year_avg"].mean()
# Out:
# job_country
# Albania        79472.500000
# Algeria        44550.000000
# Argentina     105212.343750
# Armenia        78757.000000
# Australia     118987.574324
#                   ...
# Uruguay        69333.333333
# Uzbekistan     30750.000000
# Vietnam        90927.236364
# Zambia         90670.000000
# Zimbabwe       67056.666667
# Name: salary_year_avg, Length: 108, dtype: float64

# %%
df.job_country.value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Lesotho                3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
df1.groupby("job_country")["salary_year_avg"].agg(["min","max"])
# Out:
#                  min       max
# job_country
# Albania      43200.0  157500.0
# Algeria      44100.0   45000.0
# Argentina    45000.0  222000.0
# Armenia      45000.0  128682.0
# Australia    20000.0  257500.0
# ...              ...       ...
# Uruguay      50000.0  100500.0
# Uzbekistan   30750.0   30750.0
# Vietnam      28000.0  200000.0
# Zambia       90670.0   90670.0
# Zimbabwe     47500.0   90670.0
#
# [108 rows x 2 columns]

# %%
sal_m_jts = df1.groupby("job_title_short")["salary_year_avg"].mean()
sal_m_jts = sal_m_jts.sort_values(ascending=False)

plt.barh(sal_m_jts.index, sal_m_jts.values)
plt.xlabel("Stipendio medio annuale")
plt.ylabel("Job Title Short")
plt.title("Stipendio medio annuale per job_title_short")
plt.show()
